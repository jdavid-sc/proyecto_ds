# %% [markdown]
# # Analisis de tendencias de videojuegos
# Notebook de evidencia con carga, inspección, diagnóstico y resumen estadístico.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Verificar carpeta actual y archivos disponibles

# %%
print('Ruta actual:', os.getcwd())
print('Archivos disponibles:', os.listdir())

# %% [markdown]
# ## Cargar datos desde Raw Data.csv

# %%
df = pd.read_csv('../data/raw/85._vacunas_contra_el_covid_-_19_Bucaramanga_20260327.csv')
print('Archivo cargado correctamente')

# %% [markdown]
# ## Inspección rápida

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %% [markdown]
# ## Diagnóstico principal

# %%
df.info()

# %% [markdown]
# ## Resumen estadístico

# %%
df.describe()

# %%
df.describe(include='object')

# %% [markdown]
# ## Valores nulos

# %%
df.isnull().sum()

# %% [markdown]
# ## Interpretación sugerida
# - Revisar columnas con valores nulos.
# - Confirmar tipos de datos.
# - Identificar inconsistencias antes de limpieza.
